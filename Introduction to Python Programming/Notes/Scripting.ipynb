# %% [markdown]
# https://www.anaconda.com/download/#windows
#
# https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html

# %% [markdown]
# ## [For Windows] Configuring Git Bash to Run Python

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# https://medium.com/@GalarnykMichael/install-git-on-windows-9acf2a1944f0
#
# https://git-scm.com/download/win

# %% [markdown]
# ![ad.png](data:image/png;base64,...)

# %% [markdown]
# ![spp.png](data:image/png;base64,...)

# %% [markdown]
# echo 'export PATH="$PATH:[YOUR_PATH]:[YOUR_PATH]/Scripts"' >> .bashrc

# %% [markdown]
# ![sop.png](data:image/png;base64,...)

# %% [markdown]
# `echo 'alias python="winpty python.exe"' >> .bashrc`

# %% [markdown]
# ![srr.png](data:image/png;base64,...)

# %% [markdown]
# `source .bashrc`

# %% [markdown]
# ![sl.png](data:image/png;base64,...)

# %% [markdown]
# Running a Python Script
# If you are on a Windows machine, you can follow along using git. If you are on a Mac or Linux machine, the terminal should be available with a quick search. You should then be able to follow along as shown in the video below.

# %% [markdown]
# Configure Your Own Python Programming Setup
# Now you've seen my setup, take a moment to get yourself comfortable on your own computer.
#
# Below you will find a number of different options for code editors. We recommend for all of our courses using Atom, which will work on all operating systems. If you decide not to use Atom, for first time coders Sublime is also popular.
#
# For Mac and Linux:
#
# * [Visual Studio Code](https://code.visualstudio.com/)
# * [Atom](https://github.blog/2022-06-08-sunsetting-atom/)
# * [Sublime Text](https://www.sublimetext.com/)`
# * [emacs](https://www.gnu.org/software/emacs/)
# * [vim](https://www.vim.org/)
#
# For Windows:
#
# Visual Studio Code
# * Atom
# * Sublime Text
# * [Notepad++](https://notepad-plus-plus.org/)
#
#
# Get your screen set up with a text editor, terminal/command line and the Udacity classroom in a web browser, so you can iterate on your Python script. Play with the display options to see what you find most comfortable to look at, and see if you can find a tab-to-four-spaces option - that'll be very useful for Python indentation.

# %% [markdown]
# Scripting with Raw Input

# %% [markdown]
# Scripting with Raw Input
# We can get raw input from the user with the built-in function input, which takes in an optional string argument that you can use to specify a message to show to the user when asking for input.

# %%
name = input("Enter your name: ")
print("Hello there, {}!".format(name.title()))
# Out:
# Enter your name: harii
# Hello there, Harii!

# %% [markdown]
# This prompts the user to enter a name and then uses the input in a greeting. The input function takes in whatever the user types and stores it as a string. If you want to interpret their input as something other than a string, like an integer, as in the example below, you need to wrap the result with the new type to convert it from a string.

# %%
num = int(input("Enter an integer"))
print("hello" * num)
# Out:
# Enter an integer45
# hellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohellohello

# %% [markdown]
# We can also interpret user input as a Python expression using the built-in function eval. This function evaluates a string as a line of Python.

# %%
result = eval(input("Enter an expression: "))
print(result)
# Out:
# Enter an expression: 283*34
# 9622

# %%
names = input("Enter names separated by commas: ").title().split(",")
assignments = input("Enter assignment counts separated by commas: ").split(",")
grades = input("Enter grades separated by commas: ").split(",")

message = "Hi {},\n\nThis is a reminder that you have {} assignments left to \
submit before you can graduate. You're current grade is {} and can increase \
to {} if you submit all assignments before the due date.\n\n"

for name, assignment, grade in zip(names, assignments, grades):
    print(message.format(name, assignment, grade, int(grade) + int(assignment)*2))
# Out:
# Enter names separated by commas: hari
# Enter assignment counts separated by commas: 233
# Enter grades separated by commas: 6889
# Hi Hari,
#
# This is a reminder that you have 233 assignments left to submit before you can graduate. You're current grade is 6889 and can increase to 7355 if you submit all assignments before the due date.

# %% [markdown]
# ![112.png](data:image/png;base64,...)

# %% [markdown]
# ![115.png](data:image/png;base64,...)
