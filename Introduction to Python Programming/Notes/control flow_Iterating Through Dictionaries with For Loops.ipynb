# %%
colors = ['Red', 'Blue', 'Green', 'Purple']
lower_colors = [ ]

for color in colors:
    #finish this part
    lower_colors.append(color.lower())
print(lower_colors)
# Out:
# ['red', 'blue', 'green', 'purple']

# %% [markdown]
# Method 1: Using a for loop to create a set of counters

# %%
book_title =  ['great', 'expectations','the', 'adventures', 'of', 'sherlock','holmes','the','great','gasby','hamlet','adventures','of','huckleberry','fin']

# %%
word_counter = {}

# %%
for word in book_title:
  if word not in word_counter: word_counter[word] = 1
  else: word_counter[word] += 1
print(word_counter)
# Out:
# {'great': 4, 'expectations': 2, 'the': 4, 'adventures': 4, 'of': 4, 'sherlock': 2, 'holmes': 2, 'gasby': 2, 'hamlet': 2, 'huckleberry': 2, 'fin': 2}

# %% [markdown]
# ![123.png](data:image/png;base64,...)

# %% [markdown]
# Method 2: Using the get method

# %%
book_title =  ['great', 'expectations','the', 'adventures', 'of', 'sherlock','holmes','the','great','gasby','hamlet','adventures','of','huckleberry','fin']

# %%
word_counter = {}

# %%
for word in book_title:
    word_counter[word] = word_counter.get(word, 0) + 1

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %%
print(word_counter)
# Out:
# {'great': 2, 'expectations': 1, 'the': 2, 'adventures': 2, 'of': 2, 'sherlock': 1, 'holmes': 1, 'gasby': 1, 'hamlet': 1, 'huckleberry': 1, 'fin': 1}

# %% [markdown]
# practice

# %%
transports = ["car", "Bus", "truck", "Jeep", "car", "Bus", "truck", "Tractor", "bicycle"]

# Step 1: Create an empty dictionary.
word_counter = {}
#Step 2. Iterate through each element in the list.
#If an element is already included in the dictionary, add 1 to its value.
# If not, add the element to the dictionary and set its value to 1.

for word in transports:
  if word not in word_counter:word_counter[word] = 1
  else: word_counter[word] +=1
print(word_counter)
# Out:
# {'car': 2, 'Bus': 2, 'truck': 2, 'Jeep': 1, 'Tractor': 1, 'bicycle': 1}

# %%
animals = ["dog", "cat", "mouse" , "Lion"]

animal_count = {}

for animal in animals:
  animal_count[animal] = animal_count.get(word,0) +1

print(animal_count)
# Out:
# {'dog': 1, 'cat': 1, 'mouse': 1, 'Lion': 1}

# %% [markdown]
# Iterating Through Dictionaries with For Loops

# %% [markdown]
# Iterating Through Dictionaries with For Loops
# When you iterate through a dictionary using a for loop, doing it the normal way, like
#
# for n in some_dict , will only give you access to the keys in the dictionary - which is what you'd want in some situations. In other cases, you'd want to iterate through both the keys and values in the dictionary. Let's see how this is done in an example. Consider this dictionary that uses names of actors as keys and their characters as values.

# %%
cast = {
           "House": "Man",
           "Lion": "Den",
           "bird": "Nest",
           "Fish": "water"
       }

# %% [markdown]
# If you wish to iterate through both keys and values, you can use the built-in method items like this:

# %%
for key in cast:
  print(key)
# Out:
# House
# Lion
# bird
# Fish

# %%
for key, value in cast.items():
    print("area: {}    agent: {}".format(key, value))
# Out:
# area: House    agent: Man
# area: Lion    agent: Den
# area: bird    agent: Nest
# area: Fish    agent: water

# %% [markdown]
# items is an awesome method that returns tuples of key, value pairs, which you can use to iterate over dictionaries in for loops.

# %% [markdown]
# ## Quiz: Fruit Basket - Task 1
#
# You would like to count the number of fruits in your basket. In order to do this, you have the following dictionary and list of fruits. Use the dictionary and list to count the total number of fruits, but you do not want to count the other items in your basket

# %%
# You would like to count the number of fruits in your basket.
# In order to do this, you have the following dictionary and list of
# fruits.  Use the dictionary and list to count the total number
# of fruits, but you do not want to count the other items in your basket.

result = 0
basket_items = {'apples': 4, 'oranges': 19, 'kites': 3, 'sandwiches': 8}
fruits = ['apples', 'oranges', 'pears', 'peaches', 'grapes', 'bananas']

#Iterate through the dictionary

for fruit in fruits:                       #Iterate each element in list
    result += basket_items.get(fruit, 0)   #Add to result.

print(result)
#if the key is in the list of fruits, add the value (number of fruits) to result
# Out:
# 23

# %% [markdown]
# ### Quiz: Fruit Basket - Task 2
#
# If your solution is robust, you should be able to use it with any dictionary of items to count the number of fruits in the basket. Try the loop for each of the dictionaries below to make sure it always works.

# %%
# This quiz is not graded. You can use the run button to print out your result.
#Example 1

result = 0
basket_items = {'pears': 5, 'grapes': 19, 'kites': 3, 'sandwiches': 8, 'bananas': 4}
fruits = ['apples', 'oranges', 'pears', 'peaches', 'grapes', 'bananas']

# Your previous solution here
for fruit in fruits:
    result+=basket_items.get(fruit,0)
print(result)

#Example 2

result = 0
basket_items = {'peaches': 5, 'lettuce': 2, 'kites': 3, 'sandwiches': 8, 'pears': 4}
fruits = ['apples', 'oranges', 'pears', 'peaches', 'grapes', 'bananas']

# Your previous solution here
for fruit in fruits:
    result+=basket_items.get(fruit,0)
print(result)



#Example 3

result = 0
basket_items = {'lettuce': 2, 'kites': 3, 'sandwiches': 8, 'pears': 4, 'bears': 10}
fruits = ['apples', 'oranges', 'pears', 'peaches', 'grapes', 'bananas']

# Your previous solution here
for fruit in fruits:
    result+=basket_items.get(fruit,0)
print(result)
# Out:
# 28
# 9
# 4

# %%
# You would like to count the number of fruits in your basket.
# In order to do this, you have the following dictionary and list of
# fruits.  Use the dictionary and list to count the total number
# of fruits and not_fruits.

fruit_count, not_fruit_count = 0, 0
basket_items = {'apples': 4, 'oranges': 19, 'kites': 3, 'sandwiches': 8}
fruits = ['apples', 'oranges', 'pears', 'peaches', 'grapes', 'bananas']

#Iterate through the dictionary

for item in basket_items:
  if item in fruits:
    fruit_count += basket_items[item]
  else:
    not_fruit_count += basket_items[item]
print("Total no. of fruit count:", fruit_count)
print("Total no of no fruit count", not_fruit_count)
#if the key is in the list of fruits, add to fruit_count.

#if the key is not in the list, then add to the not_fruit_count
# Out:
# Total no. of fruit count: 23
# Total no of no fruit count 11

# %%
fruit_count, not_fruit_count = 0, 0
basket_items = {'apples': 4, 'oranges': 19, 'kites': 3, 'sandwiches': 8}
fruits = ['apples', 'oranges', 'pears', 'peaches', 'grapes', 'bananas']

for item in basket_items:
    if item in fruits:
        fruit_count += basket_items[item]
    else:
        not_fruit_count += basket_items[item]

print("Total number of fruits:", fruit_count)
print("Total number of not_fruits:", not_fruit_count)
# Out:
# Total number of fruits: 23
# Total number of not_fruits: 11

# %% [markdown]
# Solution: Fruit Basket - Tasks 1 & 2

# %%
result = 0
basket_items = {'apples': 4, 'oranges': 19, 'kites': 3, 'sandwiches': 8}
fruits = ['apples', 'oranges', 'pears', 'peaches', 'grapes', 'bananas']

for object, count in basket_items.items():
   if object in fruits:
       result += count

print("There are {} fruits in the basket.".format(result))
# Out:
# There are 23 fruits in the basket.

# %%
fruit_count, not_fruit_count = 0, 0
basket_items = {'apples': 4, 'oranges': 19, 'kites': 3, 'sandwiches': 8}
fruits = ['apples', 'oranges', 'pears', 'peaches', 'grapes', 'bananas']

#Iterate through the dictionary
for object, count in basket_items.items():
    if object in fruits:
       fruit_count += count
    else:
        not_fruit_count += count

print("The number of fruits is {}.  There are {} objects that are not fruits.".format(fruit_count, not_fruit_count))
# Out:
# The number of fruits is 23.  There are 11 objects that are not fruits.
